# %%
#all spark imports
from pyspark.sql import SparkSession
from pyspark.sql.types import *
from pyspark.sql.functions import *
#instantiate the spark session
spark = SparkSession.builder.appName("Demo").getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
lineRDD = spark.sparkContext.textFile("/FileStore/tables/shakespeare_2.txt")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import re
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
words = ["Shakespeare", "When", "Lord", "Library", "GUTENBERG", "WILLIAM", "COLLEGE",  "WORLD"]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
lineRDD.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: [&#39;This eBook is for the use of anyone anywhere at no cost and with&#39;,
#  &#39;almost no restrictions whatsoever.  You may copy it, give it away or&#39;,
#  &#39;re-use it under the terms of the Project Gutenberg License included&#39;,
#  &#39;with this eBook or online at www.gutenberg.org&#39;,
#  &#39;&#39;,
#  &#39;** This is a COPYRIGHTED Project Gutenberg eBook, Details Below **&#39;,
#  &#39;**     Please follow the copyright guidelines in this file.     **&#39;,
#  &#39;&#39;,
#  &#39;Title: The Complete Works of William Shakespeare&#39;,
#  &#39;&#39;,
#  &#39;Author: William Shakespeare&#39;,
#  &#39;&#39;,
# ...

# %%
arrayRDD = lineRDD.flatMap(lambda x: re.split(r'\W+',x))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
arrayRDD.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: [&#39;This&#39;,
#  &#39;eBook&#39;,
#  &#39;is&#39;,
#  &#39;for&#39;,
#  &#39;the&#39;,
#  &#39;use&#39;,
#  &#39;of&#39;,
#  &#39;anyone&#39;,
#  &#39;anywhere&#39;,
#  &#39;at&#39;,
#  &#39;no&#39;,
#  &#39;cost&#39;,
#  &#39;and&#39;,
#  &#39;with&#39;,
#  &#39;almost&#39;,
#  &#39;no&#39;,
#  &#39;restrictions&#39;,
#  &#39;whatsoever&#39;,
#  &#39;You&#39;,
#  &#39;may&#39;,
#  &#39;copy&#39;,
#  &#39;it&#39;,
#  &#39;give&#39;,
#  &#39;it&#39;,
#  &#39;away&#39;,
#  &#39;or&#39;,
#  &#39;re&#39;,
#  &#39;use&#39;,
#  &#39;it&#39;,
#  &#39;under&#39;,
#  &#39;the&#39;,
#  &#39;terms&#39;,
#  &#39;of&#39;,
# ...

# %%
newRDD = arrayRDD.filter(lambda x: x in words)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
countRDD = newRDD.map(lambda x:(x,1))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
resultRDD = countRDD.reduceByKey(lambda x,y: x+y)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
resultRDD.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: [(&#39;Shakespeare&#39;, 22),
#  (&#39;GUTENBERG&#39;, 100),
#  (&#39;WILLIAM&#39;, 128),
#  (&#39;WORLD&#39;, 98),
#  (&#39;COLLEGE&#39;, 98),
#  (&#39;When&#39;, 406),
#  (&#39;Lord&#39;, 402),
#  (&#39;Library&#39;, 5)]</div>
